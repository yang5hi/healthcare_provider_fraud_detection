# %%
import pandas as pd


# load the data from csv to pandas dataframe
Healthcare_Inpatient_raw  = pd.read_csv('/Users/cuicuisong/Desktop/data/inpatient.csv')
Healthcare_Outpatient_raw= pd.read_csv('/Users/cuicuisong/Desktop/data/outpatient.csv')
Healthcare_Beneficiary_raw = pd.read_csv('/Users/cuicuisong/Desktop/data/beneficiary.csv')
Healthcare_Provider_raw  = pd.read_csv('/Users/cuicuisong/Desktop/data/provider.csv')

# %% [markdown]
# #### I. Merge Data

# %%
# union/concat/merge the inpatient and outpatient data
concat_df=pd.concat([Healthcare_Inpatient_raw,Healthcare_Outpatient_raw],axis=0)
concat_df.head()
# Out:
#       BeneID   ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11001  CLM46614   2009-04-12  2009-04-18  PRV55912
# 1  BENE11001  CLM66048   2009-08-31  2009-09-02  PRV55907
# 2  BENE11001  CLM68358   2009-09-17  2009-09-20  PRV56046
# 3  BENE11011  CLM38412   2009-02-14  2009-02-22  PRV52405
# 4  BENE11014  CLM63689   2009-08-13  2009-08-30  PRV56614
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                   26000          PHY390922                NaN
# 1                    5000          PHY318495          PHY318495
# 2                    5000          PHY372395                NaN
# 3                    5000          PHY369659          PHY392961
# 4                   10000          PHY379376          PHY398258
#
#   OtherPhysician AdmissionDt  ... ClmDiagnosisCode_7  ClmDiagnosisCode_8  \
# 0            NaN  2009-04-12  ...               2724               19889
# 1            NaN  2009-08-31  ...                NaN                 NaN
# 2      PHY324689  2009-09-17  ...                NaN                 NaN
# 3      PHY349768  2009-02-14  ...              25062               40390
# 4            NaN  2009-08-13  ...               5119               29620
#
#   ClmDiagnosisCode_9 ClmDiagnosisCode_10 ClmProcedureCode_1  \
# 0               5849                 NaN                NaN
# 1                NaN                 NaN             7092.0
# 2                NaN                 NaN                NaN
# 3               4019                 NaN              331.0
# 4              20300                 NaN             3893.0
#
#   ClmProcedureCode_2 ClmProcedureCode_3 ClmProcedureCode_4 ClmProcedureCode_5  \
# 0                NaN                NaN                NaN                NaN
# 1                NaN                NaN                NaN                NaN
# 2                NaN                NaN                NaN                NaN
# 3                NaN                NaN                NaN                NaN
# 4                NaN                NaN                NaN                NaN
#
#   ClmProcedureCode_6
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
#
# [5 rows x 30 columns]

# %%
# merge with beneficiary data
merge_bene_df=concat_df.merge(Healthcare_Beneficiary_raw, on='BeneID', how='left')
merge_bene_df.head()
# Out:
#       BeneID   ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11001  CLM46614   2009-04-12  2009-04-18  PRV55912
# 1  BENE11001  CLM66048   2009-08-31  2009-09-02  PRV55907
# 2  BENE11001  CLM68358   2009-09-17  2009-09-20  PRV56046
# 3  BENE11011  CLM38412   2009-02-14  2009-02-22  PRV52405
# 4  BENE11014  CLM63689   2009-08-13  2009-08-30  PRV56614
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                   26000          PHY390922                NaN
# 1                    5000          PHY318495          PHY318495
# 2                    5000          PHY372395                NaN
# 3                    5000          PHY369659          PHY392961
# 4                   10000          PHY379376          PHY398258
#
#   OtherPhysician AdmissionDt  ... ChronicCond_Depression  \
# 0            NaN  2009-04-12  ...                      1
# 1            NaN  2009-08-31  ...                      1
# 2      PHY324689  2009-09-17  ...                      1
# 3      PHY349768  2009-02-14  ...                      1
# 4            NaN  2009-08-13  ...                      1
#
#    ChronicCond_Diabetes ChronicCond_IschemicHeart ChronicCond_Osteoporasis  \
# 0                     1                         1                        2
# 1                     1                         1                        2
# 2                     1                         1                        2
# 3                     1                         2                        2
# 4                     2                         1                        2
#
#   ChronicCond_rheumatoidarthritis ChronicCond_stroke IPAnnualReimbursementAmt  \
# 0                               1                  1                    36000
# 1                               1                  1                    36000
# 2                               1                  1                    36000
# 3                               1                  1                     5000
# 4                               2                  2                    21260
#
#   IPAnnualDeductibleAmt OPAnnualReimbursementAmt OPAnnualDeductibleAmt
# 0                  3204                       60                    70
# 1                  3204                       60                    70
# 2                  3204                       60                    70
# 3                  1068                      250                   320
# 4                  2136                      120                   100
#
# [5 rows x 54 columns]

# %%
# merge with provider data
merge_provider_df=merge_bene_df.merge(Healthcare_Provider_raw, on = 'Provider', how ='left')
merge_provider_df.drop_duplicates(inplace=True)
merge_provider_df
# Out:
#             BeneID    ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0        BENE11001   CLM46614   2009-04-12  2009-04-18  PRV55912
# 1        BENE11001   CLM66048   2009-08-31  2009-09-02  PRV55907
# 2        BENE11001   CLM68358   2009-09-17  2009-09-20  PRV56046
# 3        BENE11011   CLM38412   2009-02-14  2009-02-22  PRV52405
# 4        BENE11014   CLM63689   2009-08-13  2009-08-30  PRV56614
# ...            ...        ...          ...         ...       ...
# 558206  BENE159198  CLM510792   2009-08-06  2009-08-06  PRV53699
# 558207  BENE159198  CLM551294   2009-08-29  2009-08-29  PRV53702
# 558208  BENE159198  CLM596444   2009-09-24  2009-09-24  PRV53676
# 558209  BENE159198  CLM636992   2009-10-18  2009-10-18  PRV53689
# 558210  BENE159198  CLM686139   2009-11-17  2009-11-18  PRV53689
#
#         InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                        26000          PHY390922                NaN
# 1                         5000          PHY318495          PHY318495
# 2                         5000          PHY372395                NaN
# 3                         5000          PHY369659          PHY392961
# 4                        10000          PHY379376          PHY398258
# ...                        ...                ...                ...
# 558206                     800          PHY364188          PHY364188
# 558207                     400          PHY423019          PHY332284
# 558208                      60          PHY361063                NaN
# 558209                      70          PHY403198                NaN
# 558210                      80          PHY419379                NaN
#
#        OtherPhysician AdmissionDt  ... ChronicCond_Diabetes  \
# 0                 NaN  2009-04-12  ...                    1
# 1                 NaN  2009-08-31  ...                    1
# 2           PHY324689  2009-09-17  ...                    1
# 3           PHY349768  2009-02-14  ...                    1
# 4                 NaN  2009-08-13  ...                    2
# ...               ...         ...  ...                  ...
# 558206      PHY385752         NaN  ...                    1
# 558207            NaN         NaN  ...                    1
# 558208            NaN         NaN  ...                    1
# 558209      PHY419379         NaN  ...                    1
# 558210      PHY419379         NaN  ...                    1
#
#         ChronicCond_IschemicHeart ChronicCond_Osteoporasis  \
# 0                               1                        2
# 1                               1                        2
# 2                               1                        2
# 3                               2                        2
# 4                               1                        2
# ...                           ...                      ...
# 558206                          2                        2
# 558207                          2                        2
# 558208                          2                        2
# 558209                          2                        2
# 558210                          2                        2
#
#        ChronicCond_rheumatoidarthritis ChronicCond_stroke  \
# 0                                    1                  1
# 1                                    1                  1
# 2                                    1                  1
# 3                                    1                  1
# 4                                    2                  2
# ...                                ...                ...
# 558206                               1                  2
# 558207                               1                  2
# 558208                               1                  2
# 558209                               1                  2
# 558210                               1                  2
#
#        IPAnnualReimbursementAmt IPAnnualDeductibleAmt  \
# 0                         36000                  3204
# 1                         36000                  3204
# 2                         36000                  3204
# 3                          5000                  1068
# 4                         21260                  2136
# ...                         ...                   ...
# 558206                        0                     0
# 558207                        0                     0
# 558208                        0                     0
# 558209                        0                     0
# 558210                        0                     0
#
#        OPAnnualReimbursementAmt OPAnnualDeductibleAmt PotentialFraud
# 0                            60                    70            Yes
# 1                            60                    70             No
# 2                            60                    70             No
# 3                           250                   320             No
# 4                           120                   100             No
# ...                         ...                   ...            ...
# 558206                     5470                  1870             No
# 558207                     5470                  1870             No
# 558208                     5470                  1870             No
# 558209                     5470                  1870             No
# 558210                     5470                  1870             No
#
# [558211 rows x 55 columns]

# %% [markdown]
# #### II. Group by Provider: State, county, IPAnnualReimbursementAmt and IPAnnualDeductibleAmt

# %%
# count of unique state, major state
# create a state-county feature and count of unique values (*double check the value).
# We can join and see if there are duplicate counties betwen states.
# IPAnnualReimbursementAmt and IPAnnualDeductibleAmt: Mean, Max, Sum

# %% [markdown]
# ###### 1.1. State_unique

# %%
statedf= pd.DataFrame(merge_provider_df.groupby(['Provider']).State.nunique())
statedf=statedf.rename(columns={"State": "statecount_uniq"})
statedf
# Out:
#           statecount_uniq
# Provider
# PRV51001                1
# PRV51003                3
# PRV51004                9
# PRV51005                4
# PRV51007                2
# ...                   ...
# PRV57759                1
# PRV57760                1
# PRV57761                1
# PRV57762                1
# PRV57763                3
#
# [5410 rows x 1 columns]

# %%
provider_scc_df= Healthcare_Provider_raw

# %%
# merge statecount_uniq with provider data.
provider_scc_df=provider_scc_df.merge(statedf, on = 'Provider', how ='left')
provider_scc_df
# Out:
#       Provider PotentialFraud  statecount_uniq
# 0     PRV51001             No                1
# 1     PRV51003            Yes                3
# 2     PRV51004             No                9
# 3     PRV51005            Yes                4
# 4     PRV51007             No                2
# ...        ...            ...              ...
# 5405  PRV57759             No                1
# 5406  PRV57760             No                1
# 5407  PRV57761             No                1
# 5408  PRV57762             No                1
# 5409  PRV57763             No                3
#
# [5410 rows x 3 columns]

# %% [markdown]
# ##### 1.2 State_max

# %%
statedf_max= pd.DataFrame(merge_provider_df.groupby(['Provider']).State.max())
statedf_max=statedf_max.rename(columns={"State": "state_max"})
statedf_max
# Out:
#           state_max
# Provider
# PRV51001          1
# PRV51003         11
# PRV51004         52
# PRV51005         25
# PRV51007         25
# ...             ...
# PRV57759         45
# PRV57760         45
# PRV57761         10
# PRV57762         21
# PRV57763         51
#
# [5410 rows x 1 columns]

# %%
# add column state_max to provider data.
provider_scc_df=provider_scc_df.merge(statedf_max, on = 'Provider', how ='left')
provider_scc_df
# Out:
#       Provider PotentialFraud  statecount_uniq  state_max
# 0     PRV51001             No                1          1
# 1     PRV51003            Yes                3         11
# 2     PRV51004             No                9         52
# 3     PRV51005            Yes                4         25
# 4     PRV51007             No                2         25
# ...        ...            ...              ...        ...
# 5405  PRV57759             No                1         45
# 5406  PRV57760             No                1         45
# 5407  PRV57761             No                1         10
# 5408  PRV57762             No                1         21
# 5409  PRV57763             No                3         51
#
# [5410 rows x 4 columns]

# %% [markdown]
# ##### 2.1 County_unique

# %%
# combine state and county
merge_provider_df['countyfips']=merge_provider_df['State'].astype(str)+Healthcare_Beneficiary_raw['County'].astype(str)

# %%
countydf= pd.DataFrame(merge_provider_df.groupby(['Provider']).County.nunique())
countydf=countydf.rename(columns={"County": "county_uniq"})
countydf
# Out:
#           county_uniq
# Provider
# PRV51001            7
# PRV51003           23
# PRV51004           28
# PRV51005           26
# PRV51007            6
# ...               ...
# PRV57759            2
# PRV57760            3
# PRV57761            2
# PRV57762            1
# PRV57763            4
#
# [5410 rows x 1 columns]

# %%
# add county_uniq to provider data.
provider_scc_df=provider_scc_df.merge(countydf, on = 'Provider', how ='left')
provider_scc_df
# Out:
#       Provider PotentialFraud  statecount_uniq  state_max  county_uniq
# 0     PRV51001             No                1          1            7
# 1     PRV51003            Yes                3         11           23
# 2     PRV51004             No                9         52           28
# 3     PRV51005            Yes                4         25           26
# 4     PRV51007             No                2         25            6
# ...        ...            ...              ...        ...          ...
# 5405  PRV57759             No                1         45            2
# 5406  PRV57760             No                1         45            3
# 5407  PRV57761             No                1         10            2
# 5408  PRV57762             No                1         21            1
# 5409  PRV57763             No                3         51            4
#
# [5410 rows x 5 columns]

# %% [markdown]
# ##### 2.2 County_max

# %%
countydf_max= pd.DataFrame(merge_provider_df.groupby(['Provider']).County.max())
countydf_max=countydf_max.rename(columns={"County": "county_max"})
countydf_max
# Out:
#           county_max
# Provider
# PRV51001         660
# PRV51003         851
# PRV51004         770
# PRV51005         660
# PRV51007         630
# ...              ...
# PRV57759         795
# PRV57760         770
# PRV57761         410
# PRV57762         230
# PRV57763         360
#
# [5410 rows x 1 columns]

# %%
# add county_max to provider data.
provider_scc_df=provider_scc_df.merge(countydf_max, on = 'Provider', how ='left')
provider_scc_df
# Out:
#       Provider PotentialFraud  statecount_uniq  state_max  county_uniq  \
# 0     PRV51001             No                1          1            7
# 1     PRV51003            Yes                3         11           23
# 2     PRV51004             No                9         52           28
# 3     PRV51005            Yes                4         25           26
# 4     PRV51007             No                2         25            6
# ...        ...            ...              ...        ...          ...
# 5405  PRV57759             No                1         45            2
# 5406  PRV57760             No                1         45            3
# 5407  PRV57761             No                1         10            2
# 5408  PRV57762             No                1         21            1
# 5409  PRV57763             No                3         51            4
#
#       county_max
# 0            660
# 1            851
# 2            770
# 3            660
# 4            630
# ...          ...
# 5405         795
# 5406         770
# 5407         410
# 5408         230
# 5409         360
#
# [5410 rows x 6 columns]

# %% [markdown]
# #### 3. IPAnnualReimbursementAmt
# ##### 3.1 sum_IPAnnualReimbursementAmt

# %%
IPAnnualReimbursementAmtdf = pd.DataFrame(merge_provider_df.groupby(['Provider']).IPAnnualReimbursementAmt.sum())  
IPAnnualReimbursementAmtdf=IPAnnualReimbursementAmtdf.rename(columns={"IPAnnualReimbursementAmt": "sum_IPAnnualReimbursementAmt"})
IPAnnualReimbursementAmtdf
# Out:
#           sum_IPAnnualReimbursementAmt
# Provider
# PRV51001                        440150
# PRV51003                        999000
# PRV51004                        648430
# PRV51005                       4221950
# PRV51007                        219600
# ...                                ...
# PRV57759                        110940
# PRV57760                         61280
# PRV57761                        576180
# PRV57762                         15000
# PRV57763                        424710
#
# [5410 rows x 1 columns]

# %%
provider_scc_df=provider_scc_df.merge(IPAnnualReimbursementAmtdf, on = 'Provider', how ='left')
provider_scc_df
# Out:
#       Provider PotentialFraud  statecount_uniq  state_max  county_uniq  \
# 0     PRV51001             No                1          1            7
# 1     PRV51003            Yes                3         11           23
# 2     PRV51004             No                9         52           28
# 3     PRV51005            Yes                4         25           26
# 4     PRV51007             No                2         25            6
# ...        ...            ...              ...        ...          ...
# 5405  PRV57759             No                1         45            2
# 5406  PRV57760             No                1         45            3
# 5407  PRV57761             No                1         10            2
# 5408  PRV57762             No                1         21            1
# 5409  PRV57763             No                3         51            4
#
#       county_max  sum_IPAnnualReimbursementAmt
# 0            660                        440150
# 1            851                        999000
# 2            770                        648430
# 3            660                       4221950
# 4            630                        219600
# ...          ...                           ...
# 5405         795                        110940
# 5406         770                         61280
# 5407         410                        576180
# 5408         230                         15000
# 5409         360                        424710
#
# [5410 rows x 7 columns]

# %% [markdown]
# ##### 3.2 mean_IPAnnualReimbursementAmt

# %%
IPAnnualReimbursementAmtdf_mean = pd.DataFrame(merge_provider_df.groupby(['Provider']).IPAnnualReimbursementAmt.mean())  
IPAnnualReimbursementAmtdf_mean = IPAnnualReimbursementAmtdf_mean.rename(columns={"IPAnnualReimbursementAmt": "mean_IPAnnualReimbursementAmt"})
IPAnnualReimbursementAmtdf_mean
# Out:
#           mean_IPAnnualReimbursementAmt
# Provider
# PRV51001                   17606.000000
# PRV51003                    7568.181818
# PRV51004                    4351.879195
# PRV51005                    3623.991416
# PRV51007                    3050.000000
# ...                                 ...
# PRV57759                    3962.142857
# PRV57760                    2785.454545
# PRV57761                    7026.585366
# PRV57762                   15000.000000
# PRV57763                    3599.237288
#
# [5410 rows x 1 columns]

# %%
provider_scc_df=provider_scc_df.merge(IPAnnualReimbursementAmtdf_mean, on = 'Provider', how ='left')
provider_scc_df
# Out:
#       Provider PotentialFraud  statecount_uniq  state_max  county_uniq  \
# 0     PRV51001             No                1          1            7
# 1     PRV51003            Yes                3         11           23
# 2     PRV51004             No                9         52           28
# 3     PRV51005            Yes                4         25           26
# 4     PRV51007             No                2         25            6
# ...        ...            ...              ...        ...          ...
# 5405  PRV57759             No                1         45            2
# 5406  PRV57760             No                1         45            3
# 5407  PRV57761             No                1         10            2
# 5408  PRV57762             No                1         21            1
# 5409  PRV57763             No                3         51            4
#
#       county_max  sum_IPAnnualReimbursementAmt  mean_IPAnnualReimbursementAmt
# 0            660                        440150                   17606.000000
# 1            851                        999000                    7568.181818
# 2            770                        648430                    4351.879195
# 3            660                       4221950                    3623.991416
# 4            630                        219600                    3050.000000
# ...          ...                           ...                            ...
# 5405         795                        110940                    3962.142857
# 5406         770                         61280                    2785.454545
# 5407         410                        576180                    7026.585366
# 5408         230                         15000                   15000.000000
# 5409         360                        424710                    3599.237288
#
# [5410 rows x 8 columns]

# %% [markdown]
# #####  3.3 max_IPAnnualReimbursementAmt

# %%
IPAnnualReimbursementAmtdf_max = pd.DataFrame(merge_provider_df.groupby(['Provider']).IPAnnualReimbursementAmt.max())  
IPAnnualReimbursementAmtdf_max = IPAnnualReimbursementAmtdf_max.rename(columns={"IPAnnualReimbursementAmt": "max_IPAnnualReimbursementAmt"})
IPAnnualReimbursementAmtdf_max
# Out:
#           max_IPAnnualReimbursementAmt
# Provider
# PRV51001                        143800
# PRV51003                         57000
# PRV51004                         51500
# PRV51005                        144000
# PRV51007                         24600
# ...                                ...
# PRV57759                         29000
# PRV57760                          7160
# PRV57761                         75000
# PRV57762                         15000
# PRV57763                         57000
#
# [5410 rows x 1 columns]

# %%
provider_scc_df=provider_scc_df.merge(IPAnnualReimbursementAmtdf_max, on = 'Provider', how ='left')
provider_scc_df
# Out:
#       Provider PotentialFraud  statecount_uniq  state_max  county_uniq  \
# 0     PRV51001             No                1          1            7
# 1     PRV51003            Yes                3         11           23
# 2     PRV51004             No                9         52           28
# 3     PRV51005            Yes                4         25           26
# 4     PRV51007             No                2         25            6
# ...        ...            ...              ...        ...          ...
# 5405  PRV57759             No                1         45            2
# 5406  PRV57760             No                1         45            3
# 5407  PRV57761             No                1         10            2
# 5408  PRV57762             No                1         21            1
# 5409  PRV57763             No                3         51            4
#
#       county_max  sum_IPAnnualReimbursementAmt  mean_IPAnnualReimbursementAmt  \
# 0            660                        440150                   17606.000000
# 1            851                        999000                    7568.181818
# 2            770                        648430                    4351.879195
# 3            660                       4221950                    3623.991416
# 4            630                        219600                    3050.000000
# ...          ...                           ...                            ...
# 5405         795                        110940                    3962.142857
# 5406         770                         61280                    2785.454545
# 5407         410                        576180                    7026.585366
# 5408         230                         15000                   15000.000000
# 5409         360                        424710                    3599.237288
#
#       max_IPAnnualReimbursementAmt
# 0                           143800
# 1                            57000
# 2                            51500
# 3                           144000
# 4                            24600
# ...                            ...
# 5405                         29000
# 5406                          7160
# 5407                         75000
# 5408                         15000
# 5409                         57000
#
# [5410 rows x 9 columns]

# %% [markdown]
# #### 4. IPAnnualDeductibleAmt:Sum, Mean, Max
# ##### 4.1 Sum_IPAnnualDeductibleAmt

# %%
IPAnnualDeductibleAmtdf = pd.DataFrame(merge_provider_df.groupby(['Provider']).IPAnnualDeductibleAmt.sum())  
IPAnnualDeductibleAmtdf = IPAnnualDeductibleAmtdf.rename(columns={"IPAnnualDeductibleAmt": "sum_IPAnnualDeductibleAmtdf"})
IPAnnualDeductibleAmtdf
# Out:
#           sum_IPAnnualDeductibleAmtdf
# Provider
# PRV51001                        22428
# PRV51003                       122948
# PRV51004                        64808
# PRV51005                       441724
# PRV51007                        32040
# ...                               ...
# PRV57759                        12816
# PRV57760                         9612
# PRV57761                        48060
# PRV57762                         1068
# PRV57763                        71148
#
# [5410 rows x 1 columns]

# %%
provider_scc_df= provider_scc_df.merge(IPAnnualDeductibleAmtdf, on = 'Provider', how ='left')
provider_scc_df
# Out:
#       Provider PotentialFraud  statecount_uniq  state_max  county_uniq  \
# 0     PRV51001             No                1          1            7
# 1     PRV51003            Yes                3         11           23
# 2     PRV51004             No                9         52           28
# 3     PRV51005            Yes                4         25           26
# 4     PRV51007             No                2         25            6
# ...        ...            ...              ...        ...          ...
# 5405  PRV57759             No                1         45            2
# 5406  PRV57760             No                1         45            3
# 5407  PRV57761             No                1         10            2
# 5408  PRV57762             No                1         21            1
# 5409  PRV57763             No                3         51            4
#
#       county_max  sum_IPAnnualReimbursementAmt  mean_IPAnnualReimbursementAmt  \
# 0            660                        440150                   17606.000000
# 1            851                        999000                    7568.181818
# 2            770                        648430                    4351.879195
# 3            660                       4221950                    3623.991416
# 4            630                        219600                    3050.000000
# ...          ...                           ...                            ...
# 5405         795                        110940                    3962.142857
# 5406         770                         61280                    2785.454545
# 5407         410                        576180                    7026.585366
# 5408         230                         15000                   15000.000000
# 5409         360                        424710                    3599.237288
#
#       max_IPAnnualReimbursementAmt  sum_IPAnnualDeductibleAmtdf
# 0                           143800                        22428
# 1                            57000                       122948
# 2                            51500                        64808
# 3                           144000                       441724
# 4                            24600                        32040
# ...                            ...                          ...
# 5405                         29000                        12816
# 5406                          7160                         9612
# 5407                         75000                        48060
# 5408                         15000                         1068
# 5409                         57000                        71148
#
# [5410 rows x 10 columns]

# %% [markdown]
# ##### 4.2 mean_IPAnnualDeductibleAmt

# %%
IPAnnualDeductibleAmtdf_mean = pd.DataFrame(merge_provider_df.groupby(['Provider']).IPAnnualDeductibleAmt.mean())  
IPAnnualDeductibleAmtdf_mean=IPAnnualDeductibleAmtdf_mean.rename(columns={"IPAnnualDeductibleAmt": "mean_IPAnnualDeductibleAmt"})
IPAnnualDeductibleAmtdf_mean
# Out:
#           mean_IPAnnualDeductibleAmt
# Provider
# PRV51001                  897.120000
# PRV51003                  931.424242
# PRV51004                  434.953020
# PRV51005                  379.162232
# PRV51007                  445.000000
# ...                              ...
# PRV57759                  457.714286
# PRV57760                  436.909091
# PRV57761                  586.097561
# PRV57762                 1068.000000
# PRV57763                  602.949153
#
# [5410 rows x 1 columns]

# %%
provider_scc_df= provider_scc_df.merge(IPAnnualDeductibleAmtdf_mean, on = 'Provider', how ='left')
provider_scc_df
# Out:
#       Provider PotentialFraud  statecount_uniq  state_max  county_uniq  \
# 0     PRV51001             No                1          1            7
# 1     PRV51003            Yes                3         11           23
# 2     PRV51004             No                9         52           28
# 3     PRV51005            Yes                4         25           26
# 4     PRV51007             No                2         25            6
# ...        ...            ...              ...        ...          ...
# 5405  PRV57759             No                1         45            2
# 5406  PRV57760             No                1         45            3
# 5407  PRV57761             No                1         10            2
# 5408  PRV57762             No                1         21            1
# 5409  PRV57763             No                3         51            4
#
#       county_max  sum_IPAnnualReimbursementAmt  mean_IPAnnualReimbursementAmt  \
# 0            660                        440150                   17606.000000
# 1            851                        999000                    7568.181818
# 2            770                        648430                    4351.879195
# 3            660                       4221950                    3623.991416
# 4            630                        219600                    3050.000000
# ...          ...                           ...                            ...
# 5405         795                        110940                    3962.142857
# 5406         770                         61280                    2785.454545
# 5407         410                        576180                    7026.585366
# 5408         230                         15000                   15000.000000
# 5409         360                        424710                    3599.237288
#
#       max_IPAnnualReimbursementAmt  sum_IPAnnualDeductibleAmtdf  \
# 0                           143800                        22428
# 1                            57000                       122948
# 2                            51500                        64808
# 3                           144000                       441724
# 4                            24600                        32040
# ...                            ...                          ...
# 5405                         29000                        12816
# 5406                          7160                         9612
# 5407                         75000                        48060
# 5408                         15000                         1068
# 5409                         57000                        71148
#
#       mean_IPAnnualDeductibleAmt
# 0                     897.120000
# 1                     931.424242
# 2                     434.953020
# 3                     379.162232
# 4                     445.000000
# ...                          ...
# 5405                  457.714286
# 5406                  436.909091
# 5407                  586.097561
# 5408                 1068.000000
# 5409                  602.949153
#
# [5410 rows x 11 columns]

# %% [markdown]
# ##### 4.3 max_IPAnnualDeductibleAmt

# %%
IPAnnualDeductibleAmtdf_max = pd.DataFrame(merge_provider_df.groupby(['Provider']).IPAnnualDeductibleAmt.max())  
IPAnnualDeductibleAmtdf_max=IPAnnualDeductibleAmtdf_max.rename(columns={"IPAnnualDeductibleAmt": "max_IPAnnualDeductibleAmt"})
IPAnnualDeductibleAmtdf_max
# Out:
#           max_IPAnnualDeductibleAmt
# Provider
# PRV51001                       4272
# PRV51003                       7208
# PRV51004                       7136
# PRV51005                       7136
# PRV51007                       3204
# ...                             ...
# PRV57759                       2136
# PRV57760                       1068
# PRV57761                       5340
# PRV57762                       1068
# PRV57763                       7068
#
# [5410 rows x 1 columns]

# %%
provider_scc_df= provider_scc_df.merge(IPAnnualDeductibleAmtdf_max, on = 'Provider', how ='left')
provider_scc_df
# Out:
#       Provider PotentialFraud  statecount_uniq  state_max  county_uniq  \
# 0     PRV51001             No                1          1            7
# 1     PRV51003            Yes                3         11           23
# 2     PRV51004             No                9         52           28
# 3     PRV51005            Yes                4         25           26
# 4     PRV51007             No                2         25            6
# ...        ...            ...              ...        ...          ...
# 5405  PRV57759             No                1         45            2
# 5406  PRV57760             No                1         45            3
# 5407  PRV57761             No                1         10            2
# 5408  PRV57762             No                1         21            1
# 5409  PRV57763             No                3         51            4
#
#       county_max  sum_IPAnnualReimbursementAmt  mean_IPAnnualReimbursementAmt  \
# 0            660                        440150                   17606.000000
# 1            851                        999000                    7568.181818
# 2            770                        648430                    4351.879195
# 3            660                       4221950                    3623.991416
# 4            630                        219600                    3050.000000
# ...          ...                           ...                            ...
# 5405         795                        110940                    3962.142857
# 5406         770                         61280                    2785.454545
# 5407         410                        576180                    7026.585366
# 5408         230                         15000                   15000.000000
# 5409         360                        424710                    3599.237288
#
#       max_IPAnnualReimbursementAmt  sum_IPAnnualDeductibleAmtdf  \
# 0                           143800                        22428
# 1                            57000                       122948
# 2                            51500                        64808
# 3                           144000                       441724
# 4                            24600                        32040
# ...                            ...                          ...
# 5405                         29000                        12816
# 5406                          7160                         9612
# 5407                         75000                        48060
# 5408                         15000                         1068
# 5409                         57000                        71148
#
#       mean_IPAnnualDeductibleAmt  max_IPAnnualDeductibleAmt
# 0                     897.120000                       4272
# 1                     931.424242                       7208
# 2                     434.953020                       7136
# 3                     379.162232                       7136
# 4                     445.000000                       3204
# ...                          ...                        ...
# 5405                  457.714286                       2136
# 5406                  436.909091                       1068
# 5407                  586.097561                       5340
# 5408                 1068.000000                       1068
# 5409                  602.949153                       7068
#
# [5410 rows x 12 columns]

# %%
provider_scc_df.to_csv('/Users/cuicuisong/Desktop/data/provider_scc_df.csv')
