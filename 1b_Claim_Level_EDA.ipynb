# %%
# Dependencies

import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pylab as plt
# %matplotlib inline

# %%
# Import modules for feature engineering and modelling
from sklearn.model_selection import train_test_split  # not used here, we use <2015 and >=2015 to split data
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler, StandardScaler

from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.decomposition import PCA
from sklearn.ensemble import RandomForestRegressor

# for integer encoding using sklearn
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import GridSearchCV

# Set seed for reproducibility
seed1, seed2, seed3=101,67, 42

# %%
# load the data from csv to pandas dataframe
Healthcare_Provider_raw = pd.read_csv("data/Train-1542865627584.csv")
Healthcare_Beneficiary_raw = pd.read_csv("data/Train_Beneficiarydata-1542865627584.csv")
Healthcare_Inpatient_raw = pd.read_csv("data/Train_Inpatientdata-1542865627584.csv")
Healthcare_Outpatient_raw = pd.read_csv("data/Train_Outpatientdata-1542865627584.csv")

# %%
# glance the data
display(Healthcare_Provider_raw.head())
display(Healthcare_Beneficiary_raw.head())
display(Healthcare_Inpatient_raw.head())
display(Healthcare_Outpatient_raw.head())
# Out:
#    Provider PotentialFraud
# 0  PRV51001             No
# 1  PRV51003            Yes
# 2  PRV51004             No
# 3  PRV51005            Yes
# 4  PRV51007             No
#       BeneID         DOB  DOD  Gender  Race RenalDiseaseIndicator  State  \
# 0  BENE11001  1943-01-01  NaN       1     1                     0     39
# 1  BENE11002  1936-09-01  NaN       2     1                     0     39
# 2  BENE11003  1936-08-01  NaN       1     1                     0     52
# 3  BENE11004  1922-07-01  NaN       1     1                     0     39
# 4  BENE11005  1935-09-01  NaN       1     1                     0     24
#
#    County  NoOfMonths_PartACov  NoOfMonths_PartBCov  ...  \
# 0     230                   12                   12  ...
# 1     280                   12                   12  ...
# 2     590                   12                   12  ...
# 3     270                   12                   12  ...
# 4     680                   12                   12  ...
#
# ...

# %%
# find the shape of the original data imported
display(Healthcare_Provider_raw.shape)
display(Healthcare_Beneficiary_raw.shape)
display(Healthcare_Inpatient_raw.shape)
display(Healthcare_Outpatient_raw.shape)
# Out:
# (5410, 2)
# (138556, 25)
# (40474, 30)
# (517737, 27)

# %%
Healthcare_Provider_raw['PotentialFraud_num']=Healthcare_Provider_raw['PotentialFraud'].map(lambda x:1 if (x=='Yes' or x==1) else 0)
Healthcare_Provider_raw['PotentialFraud_num'].hist()
plt.show()

# %%
import missingno as msno
msno.bar(Healthcare_Beneficiary_raw)
# Out:
# <AxesSubplot:>

# %%
msno.matrix(Healthcare_Beneficiary_raw)
# Out:
# <AxesSubplot:>

# %%
msno.bar(Healthcare_Inpatient_raw)
# Out:
# <AxesSubplot:>

# %%
msno.matrix(Healthcare_Inpatient_raw)
# Out:
# <AxesSubplot:>

# %%
msno.bar(Healthcare_Outpatient_raw)
# Out:
# <AxesSubplot:>

# %%
msno.matrix(Healthcare_Outpatient_raw)
# Out:
# <AxesSubplot:>

# %%
msno.matrix(Healthcare_Outpatient_raw)
# Out:
# <AxesSubplot:>

# %%
# check the unique value of providers in each dataframe
len(Healthcare_Outpatient_raw['Provider'].unique()), \
    len(Healthcare_Inpatient_raw['Provider'].unique()), \
    len(Healthcare_Provider_raw['Provider'].unique())
# Out:
# (5012, 2092, 5410)

# %%
# check if the provider table have all the providers listed in in/outpatient table

set(Healthcare_Provider_raw['Provider'])- \
set(set(Healthcare_Inpatient_raw['Provider']) | set(Healthcare_Outpatient_raw['Provider'])),\
set(set(Healthcare_Inpatient_raw['Provider']) | set(Healthcare_Outpatient_raw['Provider']))-\
set(Healthcare_Provider_raw['Provider'])
# Out:
# (set(), set())

# %%
# Assign inpatient data as 1, outpatient data as 0

Healthcare_Inpatient_raw['In_Out']=1
Healthcare_Outpatient_raw['In_Out']=0

# %%
# compare the column in the in/outpatient table before union

set(set(Healthcare_Inpatient_raw.columns)|set(Healthcare_Outpatient_raw.columns))\
    -set(Healthcare_Outpatient_raw.columns),\
set(set(Healthcare_Inpatient_raw.columns)|set(Healthcare_Outpatient_raw.columns))\
    -set(Healthcare_Inpatient_raw.columns)
# Out:
# ({'AdmissionDt', 'DiagnosisGroupCode', 'DischargeDt'}, set())

# %%
# union/concat the inpatient and outpatient data
concat_df=pd.concat([Healthcare_Inpatient_raw,Healthcare_Outpatient_raw],axis=0)
concat_df.head()
# Out:
#       BeneID   ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11001  CLM46614   2009-04-12  2009-04-18  PRV55912
# 1  BENE11001  CLM66048   2009-08-31  2009-09-02  PRV55907
# 2  BENE11001  CLM68358   2009-09-17  2009-09-20  PRV56046
# 3  BENE11011  CLM38412   2009-02-14  2009-02-22  PRV52405
# 4  BENE11014  CLM63689   2009-08-13  2009-08-30  PRV56614
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                   26000          PHY390922                NaN
# 1                    5000          PHY318495          PHY318495
# 2                    5000          PHY372395                NaN
# 3                    5000          PHY369659          PHY392961
# 4                   10000          PHY379376          PHY398258
#
#   OtherPhysician AdmissionDt  ... ClmDiagnosisCode_8  ClmDiagnosisCode_9  \
# 0            NaN  2009-04-12  ...              19889                5849
# 1            NaN  2009-08-31  ...                NaN                 NaN
# ...

# %%
display(concat_df.columns)
display(concat_df.shape)
# Out:
# Index(['BeneID', 'ClaimID', 'ClaimStartDt', 'ClaimEndDt', 'Provider',
#        'InscClaimAmtReimbursed', 'AttendingPhysician', 'OperatingPhysician',
#        'OtherPhysician', 'AdmissionDt', 'ClmAdmitDiagnosisCode',
#        'DeductibleAmtPaid', 'DischargeDt', 'DiagnosisGroupCode',
#        'ClmDiagnosisCode_1', 'ClmDiagnosisCode_2', 'ClmDiagnosisCode_3',
#        'ClmDiagnosisCode_4', 'ClmDiagnosisCode_5', 'ClmDiagnosisCode_6',
#        'ClmDiagnosisCode_7', 'ClmDiagnosisCode_8', 'ClmDiagnosisCode_9',
#        'ClmDiagnosisCode_10', 'ClmProcedureCode_1', 'ClmProcedureCode_2',
#        'ClmProcedureCode_3', 'ClmProcedureCode_4', 'ClmProcedureCode_5',
#        'ClmProcedureCode_6', 'In_Out'],
#       dtype='object')
# (558211, 31)

# %%
merge_bene_df=concat_df.merge(Healthcare_Beneficiary_raw, on='BeneID', how='left')
merge_bene_df.head()
# Out:
#       BeneID   ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11001  CLM46614   2009-04-12  2009-04-18  PRV55912
# 1  BENE11001  CLM66048   2009-08-31  2009-09-02  PRV55907
# 2  BENE11001  CLM68358   2009-09-17  2009-09-20  PRV56046
# 3  BENE11011  CLM38412   2009-02-14  2009-02-22  PRV52405
# 4  BENE11014  CLM63689   2009-08-13  2009-08-30  PRV56614
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                   26000          PHY390922                NaN
# 1                    5000          PHY318495          PHY318495
# 2                    5000          PHY372395                NaN
# 3                    5000          PHY369659          PHY392961
# 4                   10000          PHY379376          PHY398258
#
#   OtherPhysician AdmissionDt  ... ChronicCond_Depression  \
# 0            NaN  2009-04-12  ...                      1
# 1            NaN  2009-08-31  ...                      1
# ...

# %%
merge_provider_df=merge_bene_df.merge(Healthcare_Provider_raw[['Provider','PotentialFraud']], on = 'Provider', how ='left')
merge_provider_df.drop_duplicates(inplace=True)

# remove columns with all null values
merge_provider_df.dropna(axis=1, how='all',inplace=True)

# check the final merged dataframe
merge_provider_df
# Out:
#             BeneID    ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0        BENE11001   CLM46614   2009-04-12  2009-04-18  PRV55912
# 1        BENE11001   CLM66048   2009-08-31  2009-09-02  PRV55907
# 2        BENE11001   CLM68358   2009-09-17  2009-09-20  PRV56046
# 3        BENE11011   CLM38412   2009-02-14  2009-02-22  PRV52405
# 4        BENE11014   CLM63689   2009-08-13  2009-08-30  PRV56614
# ...            ...        ...          ...         ...       ...
# 558206  BENE159198  CLM510792   2009-08-06  2009-08-06  PRV53699
# 558207  BENE159198  CLM551294   2009-08-29  2009-08-29  PRV53702
# 558208  BENE159198  CLM596444   2009-09-24  2009-09-24  PRV53676
# 558209  BENE159198  CLM636992   2009-10-18  2009-10-18  PRV53689
# 558210  BENE159198  CLM686139   2009-11-17  2009-11-18  PRV53689
#
#         InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                        26000          PHY390922                NaN
# ...

# %%
# seperate columns into target, num, datetime, categorical

target=['PotentialFraud']
colnames=merge_provider_df.columns.to_list()
num_col_list=(merge_provider_df.describe()).columns.tolist()
datetime_col_list=['ClaimStartDt','ClaimEndDt','DischargeDt','DOB','DOD']
cat_col_list=list(set(colnames)-set(num_col_list)-set(target)-set(datetime_col_list))

# %%
# get a copy of the merged data, prepare change all to numerical
df_num=merge_provider_df.copy()

# %%
# change date column datatype to datetime

for datetime_col_name in datetime_col_list:
    df_num[datetime_col_name]=pd.to_datetime(df_num[datetime_col_name])
df_num.head()
# Out:
#       BeneID   ClaimID ClaimStartDt ClaimEndDt  Provider  \
# 0  BENE11001  CLM46614   2009-04-12 2009-04-18  PRV55912
# 1  BENE11001  CLM66048   2009-08-31 2009-09-02  PRV55907
# 2  BENE11001  CLM68358   2009-09-17 2009-09-20  PRV56046
# 3  BENE11011  CLM38412   2009-02-14 2009-02-22  PRV52405
# 4  BENE11014  CLM63689   2009-08-13 2009-08-30  PRV56614
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                   26000          PHY390922                NaN
# 1                    5000          PHY318495          PHY318495
# 2                    5000          PHY372395                NaN
# 3                    5000          PHY369659          PHY392961
# 4                   10000          PHY379376          PHY398258
#
#   OtherPhysician AdmissionDt  ... ChronicCond_Diabetes  \
# 0            NaN  2009-04-12  ...                    1
# 1            NaN  2009-08-31  ...                    1
# 2      PHY324689  2009-09-17  ...                    1
# ...

# %%
# label encode all object columns

le=LabelEncoder()

for cat_col_name in cat_col_list:
    df_num[cat_col_name]=le.fit_transform(df_num[cat_col_name])
df_num.head()
# Out:
#    BeneID  ClaimID ClaimStartDt ClaimEndDt  Provider  InscClaimAmtReimbursed  \
# 0    9381   299052   2009-04-12 2009-04-18      3928                   26000
# 1    9381   471344   2009-08-31 2009-09-02      3923                    5000
# 2    9381   491764   2009-09-17 2009-09-20      4034                    5000
# 3    9489   226452   2009-02-14 2009-02-22      1125                    5000
# 4    9518   450337   2009-08-13 2009-08-30      4490                   10000
#
#    AttendingPhysician  OperatingPhysician  OtherPhysician  AdmissionDt  ...  \
# 0               53275               35315           46457          134  ...
# 1                4951                2132           46457          275  ...
# 2               40843               35315            5201          292  ...
# 3               39020               23575           14717           77  ...
# 4               45475               25118           46457          257  ...
#
# ...

# %%
# transform target to binary code

df_num['PotentialFraud']=df_num['PotentialFraud'].map(lambda x:1 if (x=='Yes' or x==1) else 0)

df_num.head()
# Out:
#    BeneID  ClaimID ClaimStartDt ClaimEndDt  Provider  InscClaimAmtReimbursed  \
# 0    9381   299052   2009-04-12 2009-04-18      3928                   26000
# 1    9381   471344   2009-08-31 2009-09-02      3923                    5000
# 2    9381   491764   2009-09-17 2009-09-20      4034                    5000
# 3    9489   226452   2009-02-14 2009-02-22      1125                    5000
# 4    9518   450337   2009-08-13 2009-08-30      4490                   10000
#
#    AttendingPhysician  OperatingPhysician  OtherPhysician  AdmissionDt  ...  \
# 0               53275               35315           46457          134  ...
# 1                4951                2132           46457          275  ...
# 2               40843               35315            5201          292  ...
# 3               39020               23575           14717           77  ...
# 4               45475               25118           46457          257  ...
#
# ...

# %%
df_num.info()

# will drop column ClmProcedureCode_6, since it is all Null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 558211 entries, 0 to 558210
# Data columns (total 55 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   BeneID                           558211 non-null  int32
#  1   ClaimID                          558211 non-null  int32
#  2   ClaimStartDt                     558211 non-null  datetime64[ns]
#  3   ClaimEndDt                       558211 non-null  datetime64[ns]
#  4   Provider                         558211 non-null  int32
#  5   InscClaimAmtReimbursed           558211 non-null  int64
#  6   AttendingPhysician               558211 non-null  int32
#  7   OperatingPhysician               558211 non-null  int32
#  8   OtherPhysician                   558211 non-null  int32
#  9   AdmissionDt                      558211 non-null  int32
#  10  ClmAdmitDiagnosisCode            558211 non-null  int32
# ...

# %%
df_num.isnull().sum()

# will drop column ClmProcedureCode_6, since it is all Null values
# Out:
# BeneID                                  0
# ClaimID                                 0
# ClaimStartDt                            0
# ClaimEndDt                              0
# Provider                                0
# InscClaimAmtReimbursed                  0
# AttendingPhysician                      0
# OperatingPhysician                      0
# OtherPhysician                          0
# AdmissionDt                             0
# ClmAdmitDiagnosisCode                   0
# DeductibleAmtPaid                     899
# DischargeDt                        517737
# DiagnosisGroupCode                      0
# ClmDiagnosisCode_1                      0
# ClmDiagnosisCode_2                      0
# ClmDiagnosisCode_3                      0
# ClmDiagnosisCode_4                      0
# ClmDiagnosisCode_5                      0
# ClmDiagnosisCode_6                      0
# ClmDiagnosisCode_7                      0
# ClmDiagnosisCode_8                      0
# ...

# %%
df_num.describe().T
# Out:
#                                     count           mean            std  \
# BeneID                           558211.0   69139.488502   40014.023951
# ClaimID                          558211.0  279105.000000  161141.779895
# Provider                         558211.0    2582.298185    1542.465043
# InscClaimAmtReimbursed           558211.0     997.012133    3821.534891
# AttendingPhysician               558211.0   40764.226989   23766.318403
# OperatingPhysician               558211.0   31666.310809    8560.068285
# OtherPhysician                   558211.0   37939.342220   13976.363919
# AdmissionDt                      558211.0     383.842017      57.980684
# ClmAdmitDiagnosisCode            558211.0    3639.199795     958.048291
# DeductibleAmtPaid                557312.0      78.421085     274.016812
# DiagnosisGroupCode               558211.0     706.701557     117.751075
# ClmDiagnosisCode_1               558211.0    5619.543171    2970.868692
# ...

# %%
for datetime_col_name in datetime_col_list:
    print(datetime_col_name,min(df_num[datetime_col_name]), max(df_num[datetime_col_name]))
# Out:
# ClaimStartDt 2008-11-27 00:00:00 2009-12-31 00:00:00
# ClaimEndDt 2008-12-28 00:00:00 2009-12-31 00:00:00
# DischargeDt 2009-01-01 00:00:00 2009-12-31 00:00:00
# DOB 1909-01-01 00:00:00 1983-12-01 00:00:00
# DOD NaT NaT

# %%
pearsoncorr = df_num.corr(method='pearson')

display(pearsoncorr.iloc[-1:].T)
# Out:
#                                  PotentialFraud
# BeneID                                 0.003153
# ClaimID                                0.018949
# Provider                              -0.069309
# InscClaimAmtReimbursed                 0.080613
# AttendingPhysician                    -0.016997
# OperatingPhysician                    -0.027257
# OtherPhysician                        -0.003670
# AdmissionDt                           -0.099323
# ClmAdmitDiagnosisCode                 -0.047912
# DeductibleAmtPaid                      0.112305
# DiagnosisGroupCode                    -0.100603
# ClmDiagnosisCode_1                    -0.008916
# ClmDiagnosisCode_2                    -0.023850
# ClmDiagnosisCode_3                    -0.033588
# ClmDiagnosisCode_4                    -0.045189
# ClmDiagnosisCode_5                    -0.055871
# ClmDiagnosisCode_6                    -0.060939
# ClmDiagnosisCode_7                    -0.066641
# ClmDiagnosisCode_8                    -0.067815
# ...

# %%
pearson_col=list(set(num_col_list) | set(target))

# %%
pearsoncorr_num = df_num[pearson_col].corr(method='pearson')

display(pearsoncorr_num.iloc[-1:].T)
# Out:
#                                  ChronicCond_Depression
# ClmProcedureCode_5                             0.093223
# ChronicCond_Heartfailure                       0.156430
# InscClaimAmtReimbursed                        -0.017902
# ChronicCond_rheumatoidarthritis                0.123299
# In_Out                                        -0.038024
# ClmProcedureCode_1                            -0.042554
# ChronicCond_ObstrPulmonary                     0.161898
# ClmProcedureCode_2                            -0.001551
# NoOfMonths_PartACov                           -0.014568
# IPAnnualReimbursementAmt                      -0.106525
# PotentialFraud                                -0.000467
# OPAnnualDeductibleAmt                         -0.068144
# IPAnnualDeductibleAmt                         -0.131116
# County                                        -0.011099
# DeductibleAmtPaid                             -0.036013
# Race                                          -0.009682
# ...

# %%
fig = plt.figure(figsize=(25,25))
sb.heatmap(pearsoncorr_num, 
            xticklabels=pearsoncorr_num.columns,
            yticklabels=pearsoncorr_num.columns,
            cmap='RdBu_r',
            annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# <table><thead><tr><th>Aggregate Functions</th><th>Description</th></tr></thead><tbody><tr><td><strong>count()</strong></td><td>Returns count for each group</td></tr><tr><td><strong>size()</strong></td><td>Returns size for each group</td></tr><tr><td><strong>sum()</strong></td><td>Returns total sum for each group</td></tr><tr><td><strong>mean()</strong></td><td>Returns mean for each group. Same as average()</td></tr><tr><td><strong>average()</strong></td><td>Returns average for each group. Same as mean()</td></tr><tr><td><strong>std()</strong></td><td>Returns standard deviation for each group</td></tr><tr><td><strong>var()</strong></td><td>Return var for each group</td></tr><tr><td><strong>sem()</strong></td><td>Standard error of the mean of groups</td></tr><tr><td><strong>describe()</strong></td><td>Returns different statistics</td></tr><tr><td><strong>min()</strong></td><td>Returns minimum value for each group</td></tr><tr><td><strong>max()</strong></td><td>Returns maximum value for each group</td></tr><tr><td><strong>first()</strong></td><td>Returns first value for each group</td></tr><tr><td><strong>last()</strong></td><td>Returns last value for each group</td></tr><tr><td><strong>nth()</strong></td><td>Returns nth value for each group</td></tr></tbody></table>

# %%
df_num.agg(['size','count','nunique','min','max']).T
# Out:
#                                      size     count nunique  \
# BeneID                             558211    558211  138556
# ClaimID                            558211    558211  558211
# ClaimStartDt                       558211    558211     398
# ClaimEndDt                         558211    558211     366
# Provider                           558211    558211    5410
# InscClaimAmtReimbursed             558211    558211     438
# AttendingPhysician                 558211    558211   82064
# OperatingPhysician                 558211    558211   35316
# OtherPhysician                     558211    558211   46458
# AdmissionDt                        558211    558211     399
# ClmAdmitDiagnosisCode              558211    558211    4099
# DeductibleAmtPaid                558211.0  557312.0    17.0
# DischargeDt                        558211     40474     365
# DiagnosisGroupCode                 558211    558211     737
# ClmDiagnosisCode_1                 558211    558211   10451
# ...

# %%
# out patient
msno.matrix((df_num[df_num['In_Out']==0]).iloc[:,:30])
# Out:
# <AxesSubplot:>

# %%
# inpatient
msno.matrix((df_num[df_num['In_Out']==1]).iloc[:,:30])
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Transform Datatime columns + Add Code Count

# %%
# calculte claimPeriod and HospitalizedDays
# df_num = merge_provider_df.copy(deep=True)
df_num['ClaimPeriod'] = (pd.to_datetime(df_num.ClaimEndDt) - pd.to_datetime(df_num.ClaimStartDt)).dt.days + 1
df_num['HospitalizedDays'] = (pd.to_datetime(df_num.DischargeDt) - pd.to_datetime(df_num.AdmissionDt)).dt.days + 1
# make hospitallized day 0 for outpatient
df_num['HospitalizedDays'] = df_num['HospitalizedDays'].apply(lambda x : 0 if pd.isna(x) else x )

# %%
#calculate age and determine if a person is deceased. If the person is still alive, 
#use '2009-12-01' as the time we calculate age

from datetime import date, datetime
def calulateAge(dob, dod, calulationDate):
    born = dob
    if not pd.isna(dod):
        calulationDate = dod
    else:
        calulationDate = datetime.strptime(calulationDate, "%Y-%m-%d").date()
    return calulationDate.year - born.year - ((calulationDate.month, calulationDate.day) < (born.month, born.day))    


df_num['Deceased'] = df_num['DOD'].apply(lambda x : 0 if pd.isna(x) else 1) 
df_num['Age'] = df_num.apply(lambda x: calulateAge(dob = x['DOB'], dod = x['DOD'], calulationDate = '2009-12-01'), axis = 1)

# %%
'''columns: list of columns ['ClmDiagnosisCode_1', 'ClmDiagnosisCode_2']'''
def countCodeNumbers(df, columns):
    df_codes = df_num.loc[:, columns]
    codecount = df_codes.notnull().sum(axis=1)
    return codecount

diagnosis_code_columns = ['ClmDiagnosisCode_1', 'ClmDiagnosisCode_2', 'ClmDiagnosisCode_3', 'ClmDiagnosisCode_4', 'ClmDiagnosisCode_5', 
           'ClmDiagnosisCode_6', 'ClmDiagnosisCode_7', 'ClmDiagnosisCode_8', 'ClmDiagnosisCode_9', 'ClmDiagnosisCode_10' ]
procedure_code_columns = ['ClmProcedureCode_1', 'ClmProcedureCode_2', 'ClmProcedureCode_3',
       'ClmProcedureCode_4', 'ClmProcedureCode_5']

df_num['DiagnosisCodeCount'] = countCodeNumbers(df_num, diagnosis_code_columns)
df_num['ProcedureCodeCount'] = countCodeNumbers(df_num, procedure_code_columns)

# %%
df_num['DiagnosisGroupCode'] = df_num['DiagnosisGroupCode'].apply(lambda x: -999 if pd.isna(x) else x)

# %% [raw]
# y_num=df_num['PotentialFraud'].copy()
# features=list(df_num.columns)
# features.remove('Provider')  # remove does not have a return value (inplace=True)
# features.remove('PotentialFraud')  # remove does not have a return value (inplace=True)
# df_num=df_num[features]

# %%
col_names_all=list(df_num.columns)
col_names_all.remove('Provider')  # remove does not have a return value (inplace=True)
col_names_all.remove('PotentialFraud')  # remove does not have a return value (inplace=True)
col_names_all.insert(0,'Provider')
col_names_all.insert(0,'PotentialFraud')
col_names_all
df_num_reorder=df_num[col_names_all]
df_num_reorder
# Out:
#         PotentialFraud  Provider  BeneID  ClaimID ClaimStartDt ClaimEndDt  \
# 0                    1      3928    9381   299052   2009-04-12 2009-04-18
# 1                    0      3923    9381   471344   2009-08-31 2009-09-02
# 2                    0      4034    9381   491764   2009-09-17 2009-09-20
# 3                    0      1125    9489   226452   2009-02-14 2009-02-22
# 4                    0      4490    9518   450337   2009-08-13 2009-08-30
# ...                ...       ...     ...      ...          ...        ...
# 558206               0      2169   60012   338509   2009-08-06 2009-08-06
# 558207               0      2172   60012   374404   2009-08-29 2009-08-29
# 558208               0      2149   60012   414381   2009-09-24 2009-09-24
# 558209               0      2161   60012   450432   2009-10-18 2009-10-18
# 558210               0      2161   60012   494024   2009-11-17 2009-11-18
#
#         InscClaimAmtReimbursed  AttendingPhysician  OperatingPhysician  \
# ...

# %%
# log y

fig = plt.figure(figsize=(16,45),dpi=60)

for i in range(1,len(df_num_reorder.columns)):
# for i in range(len(df_num_reorder[num_col_list].columns)):
    plt.subplot(15,4,i)
    plt.hist(df_num_reorder.iloc[:,i:i+1].dropna().values)
    plt.yscale('log')
    plt.title(df_num_reorder.columns[i])
plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(16,45),dpi=60)

for i in range(1,len(df_num_reorder.columns)):
# for i in range(len(df_num_reorder[num_col_list].columns)):
    plt.subplot(15,4,i)
    plt.hist(df_num_reorder.iloc[:,i:i+1].dropna().values)
    plt.title(df_num_reorder.columns[i])
plt.tight_layout()
plt.show()

# %%
# log y hist

fig = plt.figure(figsize=(16,45),dpi=60)

for i in range(1,len(df_num_reorder.columns)):
    plt.subplot(15,4,i)
    plt.hist(df_num_reorder.loc[df_num_reorder['PotentialFraud']==0].iloc[:,i:i+1].dropna().values,
             alpha=0.7,color='gray',label='Normal')
    plt.hist(df_num_reorder.loc[df_num_reorder['PotentialFraud']==1].iloc[:,i:i+1].dropna().values,
             alpha=0.7,color='red',label='Fraud')
    plt.title(df_num_reorder.columns[i])
    plt.yscale('log')
    plt.legend(loc="upper right")
plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(16,45),dpi=60)

for i in range(1,len(df_num_reorder.columns)):
    plt.subplot(15,4,i)
    plt.hist(df_num_reorder.loc[df_num_reorder['PotentialFraud']==0].iloc[:,i:i+1].dropna().values,
             alpha=0.7,color='cadetblue',label='Normal')
    plt.hist(df_num_reorder.loc[df_num_reorder['PotentialFraud']==1].iloc[:,i:i+1].dropna().values,
             alpha=0.7,color='orange',label='Fraud')
    plt.title(df_num_reorder.columns[i])
    plt.legend(loc="upper right")
plt.tight_layout()
plt.show()
